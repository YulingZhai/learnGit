# %%
import numpy as np
# openCV == open source computer version lib
import cv2 as cv2
import matplotlib.pyplot as plt

# %%
pic = cv2.imread('./man.jpg')

# %%
cat = cv2.imread('./cat.jpg')

# %%
plt.imshow(pic)

# %%
plt.imshow(pic[:,:,::-1])

# %%
pic.shape
# Out:
# (960, 706, 3)

# %%
# 使用cv2加载已经训练好的算法，来识别图片中的人脸
face_detector = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
# 使用face_detector 来识别人脸，返回的是人脸的坐标
face = face_detector.detectMultiScale(pic)
face
# Out:
# array([[212, 104, 231, 231],
#        [588, 572,  59,  59]], dtype=int32)

# %%
face_zone = face[0]
face_zone
# Out:
# array([212, 104, 231, 231], dtype=int32)

# %%
type(face_zone)
# Out:
# numpy.ndarray

# %%
plt.imshow(cat[:,:,::-1])

# %%
head_cat = cv2.resize(cat,(231,231))
plt.imshow(head_cat)

# %%
# array([212, 104, 231, 231]
# for x in face_zone:
#     print(x,y,w,h)
pic[104:104+231,212:212+231] = head_cat

# %%
# 换头成功
plt.imshow(pic[:,:,::-1])
